# %%
import pandas as pd
import numpy as np

# %%
df_sumarized = pd.read_excel('nasa_1.xlsx')

# %%
df_index = pd.read_csv("gender-development-index.csv")

# %% [markdown]
# # DATA PREPARATION

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_numeric = df_sumarized.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

# %%
df_sumarized = df_sumarized.drop(columns=["Buffalo Stocks (1000s) 1994", "Camel Stocks (1000s) 1994"])

# %%
latin_america_countries = [
    "Argentina", "Belize", "Bolivia", "Brazil", "Chile", "Colombia",
    "Costa Rica", "Ecuador", "El Salvador", "French Guiana", "Guatemala",
    "Guyana", "Honduras", "Mexico", "Nicaragua", "Panama",
    "Paraguay", "Peru", "Suriname", "Uruguay", "Venezuela"
]

# %%
df_gender = df_index[df_index['Entity'].isin(latin_america_countries)]

# %%
df_gender_by_country = df_gender.groupby('Entity')['Gender Development Index'].mean().reset_index()

# %%
df_summerized_gender = pd.merge(df_sumarized, df_gender_by_country, left_on='Country', right_on='Entity', how='left')

# %% [markdown]
# #  M0DELING - Gender equality_Socioeconomics

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df_numeric = df_summerized_gender.drop(columns=['Entity', 'Country']).apply(pd.to_numeric, errors='coerce')

correlation_matrix = df_numeric.corr()

correlaciones_gdi = correlation_matrix['Gender Development Index'].sort_values()

mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

plt.figure(figsize=(24, 16))

sns.heatmap(correlation_matrix, mask=mask, annot=True, cmap='coolwarm', linewidths=0.5)

# Mostrar el gráfico
plt.title("Correlation Matrix - Gender Development Index")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_numeric = df_summerized_gender.drop(columns=['Entity', 'Country']).apply(pd.to_numeric, errors='coerce')

correlation_matrix = df_numeric.corr()

correlaciones_gdi = correlation_matrix['Gender Development Index'].sort_values()

top_positive = correlaciones_gdi.tail(11)
top_negative = correlaciones_gdi.head(10)

top_correlations = pd.concat([top_negative, top_positive])

plt.figure(figsize=(10, 6))
sns.barplot(x=top_correlations.values, y=top_correlations.index, palette='coolwarm')
plt.title('Top 10 most positive and negative variables regarding Gender Development Index')
plt.xlabel('Correlation')
plt.ylabel('Variables')
plt.axvline(0, color='black', linestyle='--')
plt.show()
# Out:
# <ipython-input-103-c003c0d5560f>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_correlations.values, y=top_correlations.index, palette='coolwarm')
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# # CLIMTAE CHANGE INDEX

# %%
df_cci = pd.read_excel("df_cci.xlsx")

# %%
df_cci.rename(columns={'ccindex': 'Climate Change Index'}, inplace=True)

# %%
df_summerized_cc = pd.merge(df_sumarized, df_cci, left_on='Country', right_on='Entity', how='left')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df_numeric = df_summerized_cc.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

correlation_matrix = df_numeric.corr()

mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

plt.figure(figsize=(24, 16))

sns.heatmap(correlation_matrix, mask=mask, annot=True, cmap='coolwarm', linewidths=0.5)

plt.title("Correlation Matrix - Climate Change Index")
plt.show()

# %%
correlaciones_cci = correlation_matrix['Climate Change Index'].sort_values()

# %%
correlaciones_cci
# Out:
# GDP from Agriculture (%) 1993                    -0.431194
# Projected Pop. Density (persons/km2) 2025        -0.363738
# GDP Annual Growth Rate (%) 1993                  -0.347889
# Current Pop. Density (persons/km2) 1995          -0.331704
# Agriculture Annual Withdraws (%) 1995            -0.139370
# Traditional Fuel Consumption (TJ) 1991           -0.093229
# Forest and Woodland (1000 ha) 1993               -0.060546
# Agricultural Labor Force (1000s) 1993            -0.058114
# Industry Annual Withdraws (%) 1995               -0.050179
# Known Plant Species (#) 1990's                   -0.020225
# Known Bird Species (#) 1990's                    -0.003968
# Endemic Bird Species (#) 1990's                   0.003899
# Pig Stocks (1000s) 1994                           0.012614
# Sheep Stocks (1000s) 1994                         0.024931
# Total Land Area (1000ha) 1993                     0.028566
# Total Labor Force (1000s) 1993                    0.039002
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_numeric = df_summerized_cc.drop(columns=['Entity', 'Country']).apply(pd.to_numeric, errors='coerce')
correlation_matrix = df_numeric.corr()
correlaciones_gdi = correlation_matrix['Climate Change Index'].sort_values()

top_positive = correlaciones_gdi.tail(11)
top_negative = correlaciones_gdi.head(10)

top_correlations = pd.concat([top_negative, top_positive])

plt.figure(figsize=(10, 6))
sns.barplot(x=top_correlations.values, y=top_correlations.index, palette='coolwarm')
plt.title('Top 10 most positive and negative variables regarding Climate Change Index')
plt.xlabel('Correlation')
plt.ylabel('Variables')
plt.axvline(0, color='black', linestyle='--')
plt.show()
# Out:
# <ipython-input-115-46f90162e913>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_correlations.values, y=top_correlations.index, palette='coolwarm')
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...
